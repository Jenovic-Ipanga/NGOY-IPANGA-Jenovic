# %% [markdown]
# # 1. Importation des Librairies

# %%
# importer les Packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Pour installer Tensorflow : pip install tensorflow  / conda install tensorflow
# Pour installer keras : pip install keras / conda install keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 2. charger les donnees

# %%
data = pd.read_csv('Data/DDoS_dataset.csv')
data.head()
# Out:
#       dt  switch       src       dst  pktcount  bytecount  dur   dur_nsec  \
# 0  11425       1  10.0.0.1  10.0.0.8     45304   48294064  100  716000000
# 1  11605       1  10.0.0.1  10.0.0.8    126395  134737070  280  734000000
# 2  11425       1  10.0.0.2  10.0.0.8     90333   96294978  200  744000000
# 3  11425       1  10.0.0.2  10.0.0.8     90333   96294978  200  744000000
# 4  11425       1  10.0.0.2  10.0.0.8     90333   96294978  200  744000000
#
#         tot_dur  flows  ...  pktrate  Pairflow  Protocol  port_no   tx_bytes  \
# 0  1.010000e+11      3  ...      451         0       UDP        3  143928631
# 1  2.810000e+11      2  ...      451         0       UDP        4       3842
# 2  2.010000e+11      3  ...      451         0       UDP        1       3795
# 3  2.010000e+11      3  ...      451         0       UDP        2       3688
# 4  2.010000e+11      3  ...      451         0       UDP        3       3413
#
#   rx_bytes  tx_kbps  rx_kbps  tot_kbps  label
# 0     3917        0      0.0       0.0      0
# 1     3520        0      0.0       0.0      0
# 2     1242        0      0.0       0.0      0
# 3     1492        0      0.0       0.0      0
# 4     3665        0      0.0       0.0      0
#
# [5 rows x 23 columns]

# %% [markdown]
# # 3. analyse de donnees

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104345 entries, 0 to 104344
# Data columns (total 23 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   dt           104345 non-null  int64
#  1   switch       104345 non-null  int64
#  2   src          104345 non-null  object
#  3   dst          104345 non-null  object
#  4   pktcount     104345 non-null  int64
#  5   bytecount    104345 non-null  int64
#  6   dur          104345 non-null  int64
#  7   dur_nsec     104345 non-null  int64
#  8   tot_dur      104345 non-null  float64
#  9   flows        104345 non-null  int64
#  10  packetins    104345 non-null  int64
#  11  pktperflow   104345 non-null  int64
#  12  byteperflow  104345 non-null  int64
#  13  pktrate      104345 non-null  int64
#  14  Pairflow     104345 non-null  int64
#  15  Protocol     104345 non-null  object
#  16  port_no      104345 non-null  int64
#  17  tx_bytes     104345 non-null  int64
#  18  rx_bytes     104345 non-null  int64
#  19  tx_kbps      104345 non-null  int64
#  20  rx_kbps      103839 non-null  float64
#  21  tot_kbps     103839 non-null  float64
#  22  label        104345 non-null  int64
# dtypes: float64(3), int64(17), object(3)
# memory usage: 18.3+ MB

# %%
data['src'].unique()
# Out:
# array(['10.0.0.1', '10.0.0.2', '10.0.0.4', '10.0.0.10', '10.0.0.3',
#        '10.0.0.5', '10.0.0.13', '10.0.0.6', '10.0.0.20', '10.0.0.11',
#        '10.0.0.12', '10.0.0.18', '10.0.0.8', '10.0.0.7', '10.0.0.9',
#        '10.0.0.14', '10.0.0.15', '10.0.0.16', '10.0.0.17'], dtype=object)

# %%
data['dst'].unique()
# Out:
# array(['10.0.0.8', '10.0.0.7', '10.0.0.3', '10.0.0.5', '10.0.0.10',
#        '10.0.0.13', '10.0.0.1', '10.0.0.11', '10.0.0.2', '10.0.0.4',
#        '10.0.0.9', '10.0.0.6', '10.0.0.14', '10.0.0.15', '10.0.0.12',
#        '10.0.0.16', '10.0.0.17', '10.0.0.18'], dtype=object)

# %%
data['Protocol'].unique()
# Out:
# array(['UDP', 'TCP', 'ICMP'], dtype=object)

# %%
data.drop(columns='src', inplace=True, axis=1)
data.drop(columns='dst', inplace=True, axis=1)
data.head()
# Out:
#       dt  switch  pktcount  bytecount  dur   dur_nsec       tot_dur  flows  \
# 0  11425       1     45304   48294064  100  716000000  1.010000e+11      3
# 1  11605       1    126395  134737070  280  734000000  2.810000e+11      2
# 2  11425       1     90333   96294978  200  744000000  2.010000e+11      3
# 3  11425       1     90333   96294978  200  744000000  2.010000e+11      3
# 4  11425       1     90333   96294978  200  744000000  2.010000e+11      3
#
#    packetins  pktperflow  ...  pktrate  Pairflow  Protocol port_no   tx_bytes  \
# 0       1943       13535  ...      451         0       UDP       3  143928631
# 1       1943       13531  ...      451         0       UDP       4       3842
# 2       1943       13534  ...      451         0       UDP       1       3795
# 3       1943       13534  ...      451         0       UDP       2       3688
# 4       1943       13534  ...      451         0       UDP       3       3413
#
#    rx_bytes  tx_kbps  rx_kbps  tot_kbps  label
# 0      3917        0      0.0       0.0      0
# 1      3520        0      0.0       0.0      0
# 2      1242        0      0.0       0.0      0
# 3      1492        0      0.0       0.0      0
# 4      3665        0      0.0       0.0      0
#
# [5 rows x 21 columns]

# %% [markdown]
# # 4. pretraitement

# %%
encoder = LabelEncoder()

# %%
data['Protocol'] = encoder.fit_transform(data['Protocol'])
data.head()
# Out:
#       dt  switch  pktcount  bytecount  dur   dur_nsec       tot_dur  flows  \
# 0  11425       1     45304   48294064  100  716000000  1.010000e+11      3
# 1  11605       1    126395  134737070  280  734000000  2.810000e+11      2
# 2  11425       1     90333   96294978  200  744000000  2.010000e+11      3
# 3  11425       1     90333   96294978  200  744000000  2.010000e+11      3
# 4  11425       1     90333   96294978  200  744000000  2.010000e+11      3
#
#    packetins  pktperflow  ...  pktrate  Pairflow  Protocol  port_no  \
# 0       1943       13535  ...      451         0         2        3
# 1       1943       13531  ...      451         0         2        4
# 2       1943       13534  ...      451         0         2        1
# 3       1943       13534  ...      451         0         2        2
# 4       1943       13534  ...      451         0         2        3
#
#     tx_bytes  rx_bytes  tx_kbps  rx_kbps  tot_kbps  label
# 0  143928631      3917        0      0.0       0.0      0
# 1       3842      3520        0      0.0       0.0      0
# 2       3795      1242        0      0.0       0.0      0
# 3       3688      1492        0      0.0       0.0      0
# 4       3413      3665        0      0.0       0.0      0
#
# [5 rows x 21 columns]

# %%
data['Protocol'].unique()
# Out:
# array([2, 1, 0])

# %%
data.isnull().sum()
# Out:
# dt               0
# switch           0
# pktcount         0
# bytecount        0
# dur              0
# dur_nsec         0
# tot_dur          0
# flows            0
# packetins        0
# pktperflow       0
# byteperflow      0
# pktrate          0
# Pairflow         0
# Protocol         0
# port_no          0
# tx_bytes         0
# rx_bytes         0
# tx_kbps          0
# rx_kbps        506
# tot_kbps       506
# label            0
# dtype: int64

# %%
#import seaborn as sns

# %%
#sns.heatmap(data.isnull())

# %%
# Gestion des valeurs manquantes
data['rx_kbps'].fillna(data['rx_kbps'].mean(), inplace=True)
data['tot_kbps'].fillna(data['tot_kbps'].mean(), inplace=True)
data.isnull().sum()
# Out:
# dt             0
# switch         0
# pktcount       0
# bytecount      0
# dur            0
# dur_nsec       0
# tot_dur        0
# flows          0
# packetins      0
# pktperflow     0
# byteperflow    0
# pktrate        0
# Pairflow       0
# Protocol       0
# port_no        0
# tx_bytes       0
# rx_bytes       0
# tx_kbps        0
# rx_kbps        0
# tot_kbps       0
# label          0
# dtype: int64

# %% [markdown]
# # 5. diviser les donnees train et test

# %%
data.columns
# Out:
# Index(['dt', 'switch', 'pktcount', 'bytecount', 'dur', 'dur_nsec', 'tot_dur',
#        'flows', 'packetins', 'pktperflow', 'byteperflow', 'pktrate',
#        'Pairflow', 'Protocol', 'port_no', 'tx_bytes', 'rx_bytes', 'tx_kbps',
#        'rx_kbps', 'tot_kbps', 'label'],
#       dtype='object')

# %%
#X = data.drop(columns='label', inplace=True, axis=1)
#y = data['label']
X = data.iloc[ : , :-1]
y = data.iloc[ : , -1]

# %%
X
# Out:
#            dt  switch  pktcount  bytecount  dur   dur_nsec       tot_dur  \
# 0       11425       1     45304   48294064  100  716000000  1.010000e+11
# 1       11605       1    126395  134737070  280  734000000  2.810000e+11
# 2       11425       1     90333   96294978  200  744000000  2.010000e+11
# 3       11425       1     90333   96294978  200  744000000  2.010000e+11
# 4       11425       1     90333   96294978  200  744000000  2.010000e+11
# ...       ...     ...       ...        ...  ...        ...           ...
# 104340   5262       3        79       7742   81  842000000  8.184200e+10
# 104341   5262       3        79       7742   81  842000000  8.184200e+10
# 104342   5262       3        31       3038   31  805000000  3.180500e+10
# 104343   5262       3        31       3038   31  805000000  3.180500e+10
# 104344   5262       3        31       3038   31  805000000  3.180500e+10
#
#         flows  packetins  pktperflow  byteperflow  pktrate  Pairflow  \
# 0           3       1943       13535     14428310      451         0
# 1           2       1943       13531     14424046      451         0
# 2           3       1943       13534     14427244      451         0
# 3           3       1943       13534     14427244      451         0
# 4           3       1943       13534     14427244      451         0
# ...       ...        ...         ...          ...      ...       ...
# 104340      5         10          29         2842        0         0
# 104341      5         10          29         2842        0         0
# 104342      5         10          30         2940        1         0
# 104343      5         10          30         2940        1         0
# 104344      5         10          30         2940        1         0
#
#         Protocol  port_no   tx_bytes  rx_bytes  tx_kbps  rx_kbps  tot_kbps
# 0              2        3  143928631      3917        0      0.0       0.0
# 1              2        4       3842      3520        0      0.0       0.0
# 2              2        1       3795      1242        0      0.0       0.0
# 3              2        2       3688      1492        0      0.0       0.0
# 4              2        3       3413      3665        0      0.0       0.0
# ...          ...      ...        ...       ...      ...      ...       ...
# 104340         0        1      15209     12720        1      1.0       2.0
# 104341         0        3      15099     14693        1      1.0       2.0
# 104342         0        2       3409      3731        0      0.0       0.0
# 104343         0        1      15209     12720        1      1.0       2.0
# 104344         0        3      15099     14693        1      1.0       2.0
#
# [104345 rows x 20 columns]

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 104340    0
# 104341    0
# 104342    0
# 104343    0
# 104344    0
# Name: label, Length: 104345, dtype: int64

# %%
# Splitting

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.23, random_state=40)

# %%
print("X-train:", X_train.shape)
print("X-test:", X_test.shape)
print("y-train:", y_train.shape)
print("y-train:", y_test.shape)
# Out:
# X-train: (80345, 20)
# X-test: (24000, 20)
# y-train: (80345,)
# y-train: (24000,)

# %%
X_train
# Out:
#            dt  switch  pktcount  bytecount  dur   dur_nsec       tot_dur  \
# 10499   11395       4     69567   72488814  220  746000000  2.210000e+11
# 31334    3309       6     93278   99434348  207  245000000  2.070000e+11
# 101105   6792      10       118      11564  121  447000000  1.210000e+11
# 3267     9876       2     64567   68828422  143  113000000  1.430000e+11
# 62307   29262       1       253      24794  260   81000000  2.600000e+11
# ...       ...     ...       ...        ...  ...        ...           ...
# 56760   33273       1       798      78204  818  585000000  8.190000e+11
# 93176   25170       7        12       1176   12  985000000  1.298500e+10
# 80037   14615       4     85836    4635144  151   19000000  1.510000e+11
# 30727    2829       6     98554  102693268  347  439000000  3.470000e+11
# 11590   12235       4    130900  139539400  290  749000000  2.910000e+11
#
#         flows  packetins  pktperflow  byteperflow  pktrate  Pairflow  \
# 10499       8       1943        9343      9735406      311         0
# 31334       4       7916       13523     14415518      450         0
# 101105      3       3443          30         2940        1         0
# 3267        3       1910       13526     14418716      450         0
# 62307       4       1057          29         2842        0         1
# ...       ...        ...         ...          ...      ...       ...
# 56760       7       2936          29         2842        0         1
# 93176       9       3021           0            0        0         1
# 80037       5       7385       17630       952020      587         1
# 30727       2       4440        9168      9553056      305         0
# 11590       2       2242       13685     14588210      456         0
#
#         Protocol  port_no   tx_bytes   rx_bytes  tx_kbps  rx_kbps  tot_kbps
# 10499          2        3       3413       3665        0      0.0       0.0
# 31334          2        4       5130  435554822        0   6437.0    6437.0
# 101105         0        2       5631       1632        0      0.0       0.0
# 3267           2        2       3582       1332        0      0.0       0.0
# 62307          0        3      30555  156001367        0   4972.0    4972.0
# ...          ...      ...        ...        ...      ...      ...       ...
# 56760          0        3  135645374     185738        2      2.0       4.0
# 93176          0        3  135554738  135206780        1      1.0       2.0
# 80037          1        3  150569319    8893180     3958    301.0    4259.0
# 30727          2        4       4449  245260547        0   2529.0    2529.0
# 11590          2        4       4355  143928985        0      0.0       0.0
#
# [80345 rows x 20 columns]

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 104340    0
# 104341    0
# 104342    0
# 104343    0
# 104344    0
# Name: label, Length: 104345, dtype: int64

# %%
# Standardiser les features
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
#X_train

# %% [markdown]
# # 6. Construire le Shallow Neural Network

# %%
# Creation du modele
model = Sequential()

# %%
# Ajout de la couche d'entree == couche cachee
model.add(Dense(10, input_shape=(20,), activation='relu'))
#model.add(Dense(16, input_shape=(9,), activation='relu'))
#model.add(Dense(32, activation='relu'))

# Ajout de la couche de sortie
model.add(Dense(1, activation='sigmoid'))

# Compiler le modele
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Affichage de l'architecture ou la structure du modele
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 10)             │           210 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 221 (884.00 B)
#  Trainable params: 221 (884.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# Entrainer le modele
history = model.fit(X_train, y_train, epochs=150, verbose=1, validation_data=(X_test, y_test))
# Out:
# Epoch 1/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - accuracy: 0.8025 - loss: 0.4112 - val_accuracy: 0.9399 - val_loss: 0.1764
# Epoch 2/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9441 - loss: 0.1623 - val_accuracy: 0.9494 - val_loss: 0.1412
# Epoch 3/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9511 - loss: 0.1312 - val_accuracy: 0.9559 - val_loss: 0.1231
# Epoch 4/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.9575 - loss: 0.1151 - val_accuracy: 0.9582 - val_loss: 0.1150
# Epoch 5/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9581 - loss: 0.1100 - val_accuracy: 0.9605 - val_loss: 0.1065
# Epoch 6/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9603 - loss: 0.1018 - val_accuracy: 0.9617 - val_loss: 0.1019
# Epoch 7/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9618 - loss: 0.0979 - val_accuracy: 0.9623 - val_loss: 0.0976
# Epoch 8/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9627 - loss: 0.0942 - val_accuracy: 0.9616 - val_loss: 0.0944
# Epoch 9/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.9647 - loss: 0.0896 - val_accuracy: 0.9628 - val_loss: 0.0904
# Epoch 10/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9655 - loss: 0.0862 - val_accuracy: 0.9647 - val_loss: 0.0882
# Epoch 11/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9681 - loss: 0.0816 - val_accuracy: 0.9659 - val_loss: 0.0863
# Epoch 12/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.9688 - loss: 0.0826 - val_accuracy: 0.9670 - val_loss: 0.0826
# Epoch 13/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9697 - loss: 0.0781 - val_accuracy: 0.9690 - val_loss: 0.0807
# Epoch 14/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 82s 32ms/step - accuracy: 0.9705 - loss: 0.0774 - val_accuracy: 0.9691 - val_loss: 0.0781
# Epoch 15/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9707 - loss: 0.0751 - val_accuracy: 0.9712 - val_loss: 0.0769
# Epoch 16/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9715 - loss: 0.0749 - val_accuracy: 0.9712 - val_loss: 0.0756
# Epoch 17/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9714 - loss: 0.0747 - val_accuracy: 0.9700 - val_loss: 0.0748
# Epoch 18/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9727 - loss: 0.0717 - val_accuracy: 0.9712 - val_loss: 0.0747
# Epoch 19/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.9748 - loss: 0.0674 - val_accuracy: 0.9718 - val_loss: 0.0727
# Epoch 20/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.9746 - loss: 0.0684 - val_accuracy: 0.9730 - val_loss: 0.0715
# Epoch 21/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9746 - loss: 0.0678 - val_accuracy: 0.9747 - val_loss: 0.0701
# Epoch 22/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 6556s 3s/step - accuracy: 0.9756 - loss: 0.0669 - val_accuracy: 0.9737 - val_loss: 0.0715
# Epoch 23/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9766 - loss: 0.0625 - val_accuracy: 0.9742 - val_loss: 0.0696
# Epoch 24/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9769 - loss: 0.0648 - val_accuracy: 0.9741 - val_loss: 0.0683
# Epoch 25/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9776 - loss: 0.0632 - val_accuracy: 0.9739 - val_loss: 0.0666
# Epoch 26/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9769 - loss: 0.0638 - val_accuracy: 0.9765 - val_loss: 0.0661
# Epoch 27/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9790 - loss: 0.0604 - val_accuracy: 0.9766 - val_loss: 0.0650
# Epoch 28/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9776 - loss: 0.0635 - val_accuracy: 0.9767 - val_loss: 0.0654
# Epoch 29/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9779 - loss: 0.0613 - val_accuracy: 0.9762 - val_loss: 0.0645
# Epoch 30/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9793 - loss: 0.0586 - val_accuracy: 0.9773 - val_loss: 0.0640
# Epoch 31/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9804 - loss: 0.0566 - val_accuracy: 0.9781 - val_loss: 0.0629
# Epoch 32/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9794 - loss: 0.0580 - val_accuracy: 0.9784 - val_loss: 0.0615
# Epoch 33/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9810 - loss: 0.0556 - val_accuracy: 0.9797 - val_loss: 0.0600
# Epoch 34/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9812 - loss: 0.0554 - val_accuracy: 0.9783 - val_loss: 0.0612
# Epoch 35/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9811 - loss: 0.0564 - val_accuracy: 0.9797 - val_loss: 0.0593
# Epoch 36/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9804 - loss: 0.0550 - val_accuracy: 0.9790 - val_loss: 0.0583
# Epoch 37/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9811 - loss: 0.0556 - val_accuracy: 0.9794 - val_loss: 0.0572
# Epoch 38/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9825 - loss: 0.0517 - val_accuracy: 0.9798 - val_loss: 0.0574
# Epoch 39/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9822 - loss: 0.0507 - val_accuracy: 0.9791 - val_loss: 0.0569
# Epoch 40/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9826 - loss: 0.0498 - val_accuracy: 0.9814 - val_loss: 0.0535
# Epoch 41/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9825 - loss: 0.0494 - val_accuracy: 0.9817 - val_loss: 0.0530
# Epoch 42/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9833 - loss: 0.0485 - val_accuracy: 0.9789 - val_loss: 0.0577
# Epoch 43/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9831 - loss: 0.0490 - val_accuracy: 0.9797 - val_loss: 0.0535
# Epoch 44/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9835 - loss: 0.0480 - val_accuracy: 0.9813 - val_loss: 0.0523
# Epoch 45/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9823 - loss: 0.0491 - val_accuracy: 0.9813 - val_loss: 0.0508
# Epoch 46/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9835 - loss: 0.0463 - val_accuracy: 0.9813 - val_loss: 0.0521
# Epoch 47/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9846 - loss: 0.0458 - val_accuracy: 0.9822 - val_loss: 0.0495
# Epoch 48/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9835 - loss: 0.0463 - val_accuracy: 0.9826 - val_loss: 0.0484
# Epoch 49/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9850 - loss: 0.0438 - val_accuracy: 0.9833 - val_loss: 0.0482
# Epoch 50/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9842 - loss: 0.0443 - val_accuracy: 0.9828 - val_loss: 0.0475
# Epoch 51/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9849 - loss: 0.0439 - val_accuracy: 0.9833 - val_loss: 0.0469
# Epoch 52/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9845 - loss: 0.0439 - val_accuracy: 0.9837 - val_loss: 0.0462
# Epoch 53/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9847 - loss: 0.0435 - val_accuracy: 0.9814 - val_loss: 0.0481
# Epoch 54/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9845 - loss: 0.0428 - val_accuracy: 0.9828 - val_loss: 0.0463
# Epoch 55/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9848 - loss: 0.0429 - val_accuracy: 0.9831 - val_loss: 0.0449
# Epoch 56/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9844 - loss: 0.0426 - val_accuracy: 0.9820 - val_loss: 0.0468
# Epoch 57/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9855 - loss: 0.0413 - val_accuracy: 0.9820 - val_loss: 0.0465
# Epoch 58/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9851 - loss: 0.0412 - val_accuracy: 0.9838 - val_loss: 0.0447
# Epoch 59/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9850 - loss: 0.0409 - val_accuracy: 0.9840 - val_loss: 0.0441
# Epoch 60/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9849 - loss: 0.0418 - val_accuracy: 0.9827 - val_loss: 0.0452
# Epoch 61/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9851 - loss: 0.0402 - val_accuracy: 0.9848 - val_loss: 0.0434
# Epoch 62/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9852 - loss: 0.0401 - val_accuracy: 0.9837 - val_loss: 0.0442
# Epoch 63/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9861 - loss: 0.0396 - val_accuracy: 0.9843 - val_loss: 0.0430
# Epoch 64/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9861 - loss: 0.0391 - val_accuracy: 0.9845 - val_loss: 0.0428
# Epoch 65/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9854 - loss: 0.0397 - val_accuracy: 0.9837 - val_loss: 0.0442
# Epoch 66/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9860 - loss: 0.0389 - val_accuracy: 0.9827 - val_loss: 0.0440
# Epoch 67/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9860 - loss: 0.0388 - val_accuracy: 0.9850 - val_loss: 0.0419
# Epoch 68/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9859 - loss: 0.0388 - val_accuracy: 0.9845 - val_loss: 0.0418
# Epoch 69/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9861 - loss: 0.0374 - val_accuracy: 0.9839 - val_loss: 0.0422
# Epoch 70/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9857 - loss: 0.0387 - val_accuracy: 0.9845 - val_loss: 0.0414
# Epoch 71/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9864 - loss: 0.0377 - val_accuracy: 0.9829 - val_loss: 0.0441
# Epoch 72/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9864 - loss: 0.0374 - val_accuracy: 0.9846 - val_loss: 0.0420
# Epoch 73/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9858 - loss: 0.0382 - val_accuracy: 0.9851 - val_loss: 0.0397
# Epoch 74/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9863 - loss: 0.0374 - val_accuracy: 0.9834 - val_loss: 0.0417
# Epoch 75/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9864 - loss: 0.0380 - val_accuracy: 0.9840 - val_loss: 0.0416
# Epoch 76/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9857 - loss: 0.0377 - val_accuracy: 0.9851 - val_loss: 0.0404
# Epoch 77/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9865 - loss: 0.0371 - val_accuracy: 0.9842 - val_loss: 0.0405
# Epoch 78/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9858 - loss: 0.0370 - val_accuracy: 0.9840 - val_loss: 0.0426
# Epoch 79/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9856 - loss: 0.0370 - val_accuracy: 0.9829 - val_loss: 0.0423
# Epoch 80/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9867 - loss: 0.0361 - val_accuracy: 0.9850 - val_loss: 0.0395
# Epoch 81/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9871 - loss: 0.0350 - val_accuracy: 0.9841 - val_loss: 0.0403
# Epoch 82/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9864 - loss: 0.0365 - val_accuracy: 0.9837 - val_loss: 0.0411
# Epoch 83/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9864 - loss: 0.0360 - val_accuracy: 0.9853 - val_loss: 0.0386
# Epoch 84/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9873 - loss: 0.0351 - val_accuracy: 0.9851 - val_loss: 0.0399
# Epoch 85/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9871 - loss: 0.0361 - val_accuracy: 0.9850 - val_loss: 0.0398
# Epoch 86/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9859 - loss: 0.0376 - val_accuracy: 0.9842 - val_loss: 0.0403
# Epoch 87/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9868 - loss: 0.0352 - val_accuracy: 0.9839 - val_loss: 0.0398
# Epoch 88/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9873 - loss: 0.0341 - val_accuracy: 0.9855 - val_loss: 0.0380
# Epoch 89/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9870 - loss: 0.0346 - val_accuracy: 0.9844 - val_loss: 0.0404
# Epoch 90/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9874 - loss: 0.0339 - val_accuracy: 0.9857 - val_loss: 0.0384
# Epoch 91/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9866 - loss: 0.0363 - val_accuracy: 0.9853 - val_loss: 0.0384
# Epoch 92/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9868 - loss: 0.0354 - val_accuracy: 0.9841 - val_loss: 0.0375
# Epoch 93/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9873 - loss: 0.0343 - val_accuracy: 0.9855 - val_loss: 0.0386
# Epoch 94/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.9873 - loss: 0.0342 - val_accuracy: 0.9872 - val_loss: 0.0367
# Epoch 95/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 19s 4ms/step - accuracy: 0.9871 - loss: 0.0345 - val_accuracy: 0.9862 - val_loss: 0.0366
# Epoch 96/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.9872 - loss: 0.0334 - val_accuracy: 0.9861 - val_loss: 0.0375
# Epoch 97/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9876 - loss: 0.0342 - val_accuracy: 0.9870 - val_loss: 0.0379
# Epoch 98/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9877 - loss: 0.0338 - val_accuracy: 0.9859 - val_loss: 0.0369
# Epoch 99/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9872 - loss: 0.0340 - val_accuracy: 0.9852 - val_loss: 0.0370
# Epoch 100/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9868 - loss: 0.0346 - val_accuracy: 0.9851 - val_loss: 0.0385
# Epoch 101/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9876 - loss: 0.0336 - val_accuracy: 0.9849 - val_loss: 0.0382
# Epoch 102/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9874 - loss: 0.0332 - val_accuracy: 0.9857 - val_loss: 0.0376
# Epoch 103/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9881 - loss: 0.0326 - val_accuracy: 0.9868 - val_loss: 0.0361
# Epoch 104/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9880 - loss: 0.0321 - val_accuracy: 0.9858 - val_loss: 0.0359
# Epoch 105/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9875 - loss: 0.0329 - val_accuracy: 0.9871 - val_loss: 0.0356
# Epoch 106/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9885 - loss: 0.0325 - val_accuracy: 0.9860 - val_loss: 0.0366
# Epoch 107/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9881 - loss: 0.0323 - val_accuracy: 0.9862 - val_loss: 0.0367
# Epoch 108/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.9881 - loss: 0.0316 - val_accuracy: 0.9866 - val_loss: 0.0350
# Epoch 109/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9881 - loss: 0.0322 - val_accuracy: 0.9859 - val_loss: 0.0362
# Epoch 110/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9876 - loss: 0.0326 - val_accuracy: 0.9857 - val_loss: 0.0371
# Epoch 111/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9880 - loss: 0.0323 - val_accuracy: 0.9872 - val_loss: 0.0348
# Epoch 112/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9875 - loss: 0.0327 - val_accuracy: 0.9868 - val_loss: 0.0358
# Epoch 113/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9874 - loss: 0.0326 - val_accuracy: 0.9863 - val_loss: 0.0367
# Epoch 114/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9873 - loss: 0.0329 - val_accuracy: 0.9869 - val_loss: 0.0355
# Epoch 115/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9884 - loss: 0.0307 - val_accuracy: 0.9858 - val_loss: 0.0350
# Epoch 116/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9876 - loss: 0.0316 - val_accuracy: 0.9857 - val_loss: 0.0367
# Epoch 117/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9887 - loss: 0.0309 - val_accuracy: 0.9862 - val_loss: 0.0357
# Epoch 118/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9881 - loss: 0.0316 - val_accuracy: 0.9861 - val_loss: 0.0348
# Epoch 119/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9880 - loss: 0.0313 - val_accuracy: 0.9865 - val_loss: 0.0351
# Epoch 120/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9875 - loss: 0.0315 - val_accuracy: 0.9880 - val_loss: 0.0331
# Epoch 121/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9884 - loss: 0.0300 - val_accuracy: 0.9862 - val_loss: 0.0340
# Epoch 122/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9878 - loss: 0.0319 - val_accuracy: 0.9872 - val_loss: 0.0336
# Epoch 123/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9877 - loss: 0.0316 - val_accuracy: 0.9870 - val_loss: 0.0347
# Epoch 124/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9885 - loss: 0.0303 - val_accuracy: 0.9881 - val_loss: 0.0336
# Epoch 125/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9878 - loss: 0.0313 - val_accuracy: 0.9871 - val_loss: 0.0345
# Epoch 126/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9884 - loss: 0.0307 - val_accuracy: 0.9867 - val_loss: 0.0341
# Epoch 127/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9892 - loss: 0.0293 - val_accuracy: 0.9865 - val_loss: 0.0347
# Epoch 128/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9882 - loss: 0.0311 - val_accuracy: 0.9877 - val_loss: 0.0323
# Epoch 129/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9883 - loss: 0.0303 - val_accuracy: 0.9860 - val_loss: 0.0331
# Epoch 130/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9874 - loss: 0.0319 - val_accuracy: 0.9865 - val_loss: 0.0335
# Epoch 131/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9884 - loss: 0.0305 - val_accuracy: 0.9877 - val_loss: 0.0321
# Epoch 132/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9884 - loss: 0.0300 - val_accuracy: 0.9870 - val_loss: 0.0331
# Epoch 133/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9888 - loss: 0.0301 - val_accuracy: 0.9868 - val_loss: 0.0353
# Epoch 134/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9882 - loss: 0.0296 - val_accuracy: 0.9870 - val_loss: 0.0323
# Epoch 135/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9893 - loss: 0.0285 - val_accuracy: 0.9877 - val_loss: 0.0322
# Epoch 136/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9883 - loss: 0.0302 - val_accuracy: 0.9875 - val_loss: 0.0322
# Epoch 137/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9878 - loss: 0.0311 - val_accuracy: 0.9875 - val_loss: 0.0325
# Epoch 138/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9891 - loss: 0.0289 - val_accuracy: 0.9871 - val_loss: 0.0318
# Epoch 139/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9889 - loss: 0.0286 - val_accuracy: 0.9877 - val_loss: 0.0324
# Epoch 140/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9881 - loss: 0.0297 - val_accuracy: 0.9877 - val_loss: 0.0316
# Epoch 141/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9889 - loss: 0.0290 - val_accuracy: 0.9870 - val_loss: 0.0330
# Epoch 142/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9873 - loss: 0.0314 - val_accuracy: 0.9883 - val_loss: 0.0313
# Epoch 143/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9890 - loss: 0.0289 - val_accuracy: 0.9885 - val_loss: 0.0306
# Epoch 144/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9896 - loss: 0.0284 - val_accuracy: 0.9872 - val_loss: 0.0334
# Epoch 145/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9888 - loss: 0.0284 - val_accuracy: 0.9875 - val_loss: 0.0319
# Epoch 146/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9880 - loss: 0.0294 - val_accuracy: 0.9872 - val_loss: 0.0311
# Epoch 147/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9886 - loss: 0.0294 - val_accuracy: 0.9871 - val_loss: 0.0325
# Epoch 148/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9886 - loss: 0.0294 - val_accuracy: 0.9872 - val_loss: 0.0334
# Epoch 149/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9885 - loss: 0.0298 - val_accuracy: 0.9885 - val_loss: 0.0306
# Epoch 150/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.9887 - loss: 0.0293 - val_accuracy: 0.9868 - val_loss: 0.0326

# %% [markdown]
# # 7. Visualiser l’évolution de l’entrainement du réseau de neurone

# %%
history

# %%
# Visualiser l’évolution de l’entrainement du réseau de neurone
import matplotlib.pyplot as plt

# %%
epoch_accuracy = history.history['accuracy']
epoch_loss = history.history['loss']

epoch_val_accuracy = history.history['val_accuracy']
epoch_val_loss = history.history['val_loss']

# %%
plt.figure(figsize=(15, 6))
plt.plot(range(0, len(epoch_accuracy)), epoch_accuracy, color='blue', label='Training Accuracy')
plt.plot(range(0, len(epoch_loss)), epoch_loss, color='red', label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Valeur')
plt.title('Accuracy Vs Loss')
plt.legend()
plt.plot()
plt.show()

# %%
plt.figure(figsize=(15, 6))
plt.plot(range(0, len(epoch_accuracy)), epoch_accuracy, color='blue', label='Training Accuracy')
plt.plot(range(0, len(epoch_val_accuracy)), epoch_val_accuracy, color='red', label='Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training Accuracy Vs Test Accuracy')
plt.legend()
plt.plot()
plt.show()

# %%
plt.figure(figsize=(15, 6))
plt.plot(range(0, len(epoch_loss)), epoch_loss, color='blue', label='Training Loss')
plt.plot(range(0, len(epoch_val_loss)), epoch_val_loss, color='red', label='Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss Vs Test Loss')
plt.legend()
plt.plot()
plt.show()

# %% [markdown]
# # 8. Evaluer le modèle

# %%
model.evaluate(X_test, y_test)
# Out:
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9875 - loss: 0.0303
# [0.032625820487737656, 0.9867916703224182]

# %% [markdown]
# # deep learning model

# %%
model_dnn = Sequential()

# %%
opt = 'adam'

# %%
# 1ere couche
model_dnn.add(Dense(32,input_shape=(20,), activation='relu'))


# 2eme couche
model_dnn.add(Dense(32, activation='relu'))
model_dnn.add(Dense(64, activation='relu'))
model_dnn.add(Dense(128, activation='relu'))
model_dnn.add(Dense(32, activation='relu'))

# la couche de sortie
model_dnn.add(Dense(1,activation='sigmoid'))

# compliler le modele
model_dnn.compile(optimizer=opt, loss='binary_crossentroy',metrics=['accuracy'])

model_dnn.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                 │ (None, 32)             │           672 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,321 (63.75 KB)
#  Trainable params: 16,321 (63.75 KB)
#  Non-trainable params: 0 (0.00 B)
